# %% [markdown]
# # Data visualization Project
#
# # Student name:- Nisha Jondhale
# # project name:- Restaurant-Sales-Data using Data Visualization
# # objective :- the objective of this project is to analyze restaurant sales data using numpy,pandas,matplotlib and seaborn to uncover patterns in revenue, customer preferences, and sales data trends. the goal is to gain insights that can help improve menu stratergy, payment options, and overall business performances.

# %%
# RESTAURANT SALES DATA ANALYSIS PROJECT

# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/kaggle/input/restaurant-sales-data/9. Sales-Data-Analysis.csv')
print(df)
# Out:
#      Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0       10452  07-11-2022               Fries   3.49    573.07       Online
# 1       10453  07-11-2022           Beverages   2.95    745.76       Online
# 2       10454  07-11-2022       Sides & Other   4.99    200.40     In-store
# 3       10455  08-11-2022             Burgers  12.99    569.67     In-store
# 4       10456  08-11-2022  Chicken Sandwiches   9.95    201.01     In-store
# ..        ...         ...                 ...    ...       ...           ...
# 249     10709  28-12-2022       Sides & Other   4.99    200.40   Drive-thru
# 250     10710  29-12-2022             Burgers  12.99    754.43   Drive-thru
# 251     10711  29-12-2022  Chicken Sandwiches   9.95    281.41   Drive-thru
# 252     10712  29-12-2022               Fries   3.49    630.37   Drive-thru
# 253     10713  29-12-2022           Beverages   2.95    677.97   Drive-thru
#
#     Payment Method             Manager    City
# ...

# %%
# Show first 5 rows
df.head()
# Out:
#    Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0     10452  07-11-2022               Fries   3.49    573.07       Online
# 1     10453  07-11-2022           Beverages   2.95    745.76       Online
# 2     10454  07-11-2022       Sides & Other   4.99    200.40     In-store
# 3     10455  08-11-2022             Burgers  12.99    569.67     In-store
# 4     10456  08-11-2022  Chicken Sandwiches   9.95    201.01     In-store
#
#   Payment Method             Manager    City
# 0      Gift Card    Tom      Jackson  London
# 1      Gift Card         Pablo Perez  Madrid
# 2      Gift Card       Joao    Silva  Lisbon
# 3    Credit Card       Walter Muller  Berlin
# 4    Credit Card       Walter Muller  Berlin

# %%
# Show last 5 rows
df.tail()
# Out:
#      Order ID        Date             Product  Price  Quantity Purchase Type  \
# 249     10709  28-12-2022       Sides & Other   4.99    200.40   Drive-thru
# 250     10710  29-12-2022             Burgers  12.99    754.43   Drive-thru
# 251     10711  29-12-2022  Chicken Sandwiches   9.95    281.41   Drive-thru
# 252     10712  29-12-2022               Fries   3.49    630.37   Drive-thru
# 253     10713  29-12-2022           Beverages   2.95    677.97   Drive-thru
#
#     Payment Method        Manager    City
# 249      Gift Card  Walter Muller  Berlin
# 250      Gift Card  Walter Muller  Berlin
# 251      Gift Card  Walter Muller  Berlin
# 252      Gift Card  Walter Muller  Berlin
# 253      Gift Card  Walter Muller  Berlin

# %%
# DataFrame structure, dtypes, non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    int64
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    float64
#  4   Quantity        254 non-null    float64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 18.0+ KB

# %%
# Numeric + object summaries (transposed for readability)
df.describe(include='all').T
# Out:
#                 count unique           top freq          mean         std  \
# Order ID        254.0    NaN           NaN  NaN  10584.133858   75.889181
# Date              254     53    03-12-2022    5           NaN         NaN
# Product           254      5       Burgers   52           NaN         NaN
# Price           254.0    NaN           NaN  NaN      7.102323    4.341855
# Quantity        254.0    NaN           NaN  NaN    460.611457  214.888699
# Purchase Type     254      3       Online   107           NaN         NaN
# Payment Method    254      3   Credit Card  120           NaN         NaN
# Manager           254     14   Tom Jackson   74           NaN         NaN
# City              254      5        London   75           NaN         NaN
#
#                     min       25%      50%       75%      max
# Order ID        10452.0  10520.25  10583.5  10649.75  10713.0
# Date                NaN       NaN      NaN       NaN      NaN
# ...

# %%
# List columns (attribute)
list(df.columns)
# Out:
# ['Order ID',
#  'Date',
#  'Product',
#  'Price',
#  'Quantity',
#  'Purchase Type',
#  'Payment Method',
#  'Manager',
#  'City']

# %%
# Count of nulls per column (common usage)
df.isnull().sum()
# Out:
# Order ID          0
# Date              0
# Product           0
# Price             0
# Quantity          0
# Purchase Type     0
# Payment Method    0
# Manager           0
# City              0
# dtype: int64

# %%
# Count of non-null per column
df.notnull().sum()
# Out:
# Order ID          254
# Date              254
# Product           254
# Price             254
# Quantity          254
# Purchase Type     254
# Payment Method    254
# Manager           254
# City              254
# dtype: int64

# %%
# Drop exact duplicate rows
df_nodup = df.drop_duplicates().reset_index(drop=True)
print("Rows removed:", df.shape[0] - df_nodup.shape[0])
# Out:
# Rows removed: 0

# %%
# Count duplicate rows (exact duplicates)
df.duplicated().sum()
# Out:
# 0

# %%
# Number of unique values per column
df.nunique()
# Out:
# Order ID          254
# Date               53
# Product             5
# Price               7
# Quantity           29
# Purchase Type       3
# Payment Method      3
# Manager            14
# City                5
# dtype: int64

# %%
# Mean of numeric columns
df.mean(numeric_only=True)
# Out:
# Order ID    10584.133858
# Price           7.102323
# Quantity      460.611457
# dtype: float64

# %%
# Median of numeric columns
df.median(numeric_only=True)
# Out:
# Order ID    10583.50
# Price           4.99
# Quantity      538.88
# dtype: float64

# %%
# Maximum values (largest order total)
df.max(numeric_only=True)
# Out:
# Order ID    10713.00
# Price          29.05
# Quantity      754.43
# dtype: float64

# %%
# Standard deviation (spread)
df.std(numeric_only=True)
# Out:
# Order ID     75.889181
# Price         4.341855
# Quantity    214.888699
# dtype: float64

# %%
# Minimum values (e.g., smallest order total / smallest qty)
df.min(numeric_only=True)
# Out:
# Order ID    10452.00
# Price           2.95
# Quantity      200.40
# dtype: float64

# %%
# Variance
df.var(numeric_only=True)
# Out:
# Order ID     5759.167782
# Price          18.851702
# Quantity    46177.153050
# dtype: float64

# %%
# Correlation matrix for numeric columns
df.corr(numeric_only=True)
# Out:
#           Order ID     Price  Quantity
# Order ID  1.000000 -0.061826  0.081784
# Price    -0.061826  1.000000 -0.260207
# Quantity  0.081784 -0.260207  1.000000

# %%
# Covariance matrix
df.cov(numeric_only=True)
# Out:
#              Order ID       Price      Quantity
# Order ID  5759.167782  -20.371537   1333.710634
# Price      -20.371537   18.851702   -242.777085
# Quantity  1333.710634 -242.777085  46177.153050

# %%
# Select rows by index range
df.iloc[0:10]   # first 10 rows
# Out:
#    Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0     10452  07-11-2022               Fries   3.49    573.07       Online
# 1     10453  07-11-2022           Beverages   2.95    745.76       Online
# 2     10454  07-11-2022       Sides & Other   4.99    200.40     In-store
# 3     10455  08-11-2022             Burgers  12.99    569.67     In-store
# 4     10456  08-11-2022  Chicken Sandwiches   9.95    201.01     In-store
# 5     10457  08-11-2022               Fries   3.49    573.07     In-store
# 6     10459  08-11-2022       Sides & Other   4.99    200.40     In-store
# 7     10460  09-11-2022             Burgers  12.99    554.27     In-store
# 8     10461  09-11-2022  Chicken Sandwiches   9.95    201.01     In-store
# 9     10462  09-11-2022               Fries   3.49    573.07     In-store
#
#   Payment Method             Manager    City
# 0      Gift Card    Tom      Jackson  London
# 1      Gift Card         Pablo Perez  Madrid
# ...

# %%
# Kurtosis
df.kurt(numeric_only=True)
# Out:
# Order ID   -1.209294
# Price       1.938642
# Quantity   -1.726073
# dtype: float64

# %%
# Skewness
df.skew(numeric_only=True)
# Out:
# Order ID   -0.026856
# Price       1.080132
# Quantity   -0.211871
# dtype: float64

# %%
# Variance of numeric columns
df.var(numeric_only=True)
# Out:
# Order ID     5759.167782
# Price          18.851702
# Quantity    46177.153050
# dtype: float64

# %%
# Get values as NumPy array
df.values[:5]
# Out:
# array([[10452, '07-11-2022', 'Fries', 3.49, 573.07, 'Online ',
#         ' Gift Card', 'Tom      Jackson', 'London'],
#        [10453, '07-11-2022', 'Beverages', 2.95, 745.76, 'Online ',
#         ' Gift Card', '       Pablo Perez', 'Madrid'],
#        [10454, '07-11-2022', 'Sides & Other', 4.99, 200.4, 'In-store ',
#         ' Gift Card', 'Joao    Silva', 'Lisbon'],
#        [10455, '08-11-2022', 'Burgers', 12.99, 569.67, 'In-store ',
#         ' Credit Card', 'Walter Muller', 'Berlin'],
#        [10456, '08-11-2022', 'Chicken Sandwiches', 9.95, 201.01,
#         'In-store ', ' Credit Card', 'Walter Muller', 'Berlin']],
#       dtype=object)

# %%
# Select specific rows and columns
df.loc[0:5,]
# Out:
#    Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0     10452  07-11-2022               Fries   3.49    573.07       Online
# 1     10453  07-11-2022           Beverages   2.95    745.76       Online
# 2     10454  07-11-2022       Sides & Other   4.99    200.40     In-store
# 3     10455  08-11-2022             Burgers  12.99    569.67     In-store
# 4     10456  08-11-2022  Chicken Sandwiches   9.95    201.01     In-store
# 5     10457  08-11-2022               Fries   3.49    573.07     In-store
#
#   Payment Method             Manager    City
# 0      Gift Card    Tom      Jackson  London
# 1      Gift Card         Pablo Perez  Madrid
# 2      Gift Card       Joao    Silva  Lisbon
# 3    Credit Card       Walter Muller  Berlin
# 4    Credit Card       Walter Muller  Berlin
# 5    Credit Card       Remy    Monet   Paris

# %%
 
display(df.sample(min(5, len(df)), random_state=42))
# Out:
#      Order ID        Date             Product  Price  Quantity Purchase Type  \
# 190     10650  17-12-2022             Burgers  12.99    585.07       Online
# 6       10459  08-11-2022       Sides & Other   4.99    200.40     In-store
# 79      10536  24-11-2022  Chicken Sandwiches   9.95    201.01   Drive-thru
# 205     10665  20-12-2022             Burgers  12.99    646.65     In-store
# 117     10577  02-12-2022               Fries   3.49    630.37       Online
#
#     Payment Method        Manager    City
# 190      Gift Card     Joao Silva  Lisbon
# 6      Credit Card  Walter Muller  Berlin
# 79     Credit Card    Pablo Perez  Madrid
# 205           Cash     Joao Silva  Lisbon
# 117    Credit Card     Remy Monet   Paris

# %%
display(df.fillna({"price_per_unit": 0}).head(3))
display(df.dropna(how="all").head(3))
# Out:
#    Order ID        Date        Product  Price  Quantity Purchase Type  \
# 0     10452  07-11-2022          Fries   3.49    573.07       Online
# 1     10453  07-11-2022      Beverages   2.95    745.76       Online
# 2     10454  07-11-2022  Sides & Other   4.99    200.40     In-store
#
#   Payment Method             Manager    City
# 0      Gift Card    Tom      Jackson  London
# 1      Gift Card         Pablo Perez  Madrid
# 2      Gift Card       Joao    Silva  Lisbon
#    Order ID        Date        Product  Price  Quantity Purchase Type  \
# 0     10452  07-11-2022          Fries   3.49    573.07       Online
# 1     10453  07-11-2022      Beverages   2.95    745.76       Online
# 2     10454  07-11-2022  Sides & Other   4.99    200.40     In-store
#
#   Payment Method             Manager    City
# 0      Gift Card    Tom      Jackson  London
# 1      Gift Card         Pablo Perez  Madrid
# 2      Gift Card       Joao    Silva  Lisbon

# %%
import pandas as pd


df = pd.read_csv("/kaggle/input/restaurant-sales-data/9. Sales-Data-Analysis.csv")

# Rename a column (example: 'Total' → 'Total_Sales')
df.rename(columns={'Total': 'Total_Sales'}).head()

#  Rename multiple columns at once
df.rename(columns={'Total': 'Total_Sales', 'Quantity': 'Qty'}).head()
# Out:
#    Order ID        Date             Product  Price     Qty Purchase Type  \
# 0     10452  07-11-2022               Fries   3.49  573.07       Online
# 1     10453  07-11-2022           Beverages   2.95  745.76       Online
# 2     10454  07-11-2022       Sides & Other   4.99  200.40     In-store
# 3     10455  08-11-2022             Burgers  12.99  569.67     In-store
# 4     10456  08-11-2022  Chicken Sandwiches   9.95  201.01     In-store
#
#   Payment Method             Manager    City
# 0      Gift Card    Tom      Jackson  London
# 1      Gift Card         Pablo Perez  Madrid
# 2      Gift Card       Joao    Silva  Lisbon
# 3    Credit Card       Walter Muller  Berlin
# 4    Credit Card       Walter Muller  Berlin

# %%
#  Check memory usage
df.memory_usage(deep=True)
# Out:
# Index               132
# Order ID           2032
# Date              17018
# Product           17120
# Price              2032
# Quantity           2032
# Purchase Type     16672
# Payment Method    16878
# Manager           17325
# City              15974
# dtype: int64

# %%
# 4. Drop a column (example: 'Discount' if it exists)
df.drop(columns=['Discount'], errors='ignore').head()
# Out:
#    Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0     10452  07-11-2022               Fries   3.49    573.07       Online
# 1     10453  07-11-2022           Beverages   2.95    745.76       Online
# 2     10454  07-11-2022       Sides & Other   4.99    200.40     In-store
# 3     10455  08-11-2022             Burgers  12.99    569.67     In-store
# 4     10456  08-11-2022  Chicken Sandwiches   9.95    201.01     In-store
#
#   Payment Method             Manager    City
# 0      Gift Card    Tom      Jackson  London
# 1      Gift Card         Pablo Perez  Madrid
# 2      Gift Card       Joao    Silva  Lisbon
# 3    Credit Card       Walter Muller  Berlin
# 4    Credit Card       Walter Muller  Berlin

# %%
df_renamed = df.rename(columns=lambda c: c.replace("used","u"))
display(df_renamed.head(2))
# Out:
#    Order ID        Date    Product  Price  Quantity Purchase Type  \
# 0     10452  07-11-2022      Fries   3.49    573.07       Online
# 1     10453  07-11-2022  Beverages   2.95    745.76       Online
#
#   Payment Method             Manager    City
# 0      Gift Card    Tom      Jackson  London
# 1      Gift Card         Pablo Perez  Madrid

# %%
# Drop specific rows by index
df.drop([0,1], axis=0).head()
# Out:
#    Order ID        Date             Product  Price  Quantity Purchase Type  \
# 2     10454  07-11-2022       Sides & Other   4.99    200.40     In-store
# 3     10455  08-11-2022             Burgers  12.99    569.67     In-store
# 4     10456  08-11-2022  Chicken Sandwiches   9.95    201.01     In-store
# 5     10457  08-11-2022               Fries   3.49    573.07     In-store
# 6     10459  08-11-2022       Sides & Other   4.99    200.40     In-store
#
#   Payment Method        Manager    City
# 2      Gift Card  Joao    Silva  Lisbon
# 3    Credit Card  Walter Muller  Berlin
# 4    Credit Card  Walter Muller  Berlin
# 5    Credit Card  Remy    Monet   Paris
# 6    Credit Card  Walter Muller  Berlin

# %%
print(np.arange(5))
# Out:
# [0 1 2 3 4]

# %%
sales = df.to_numpy()
sales[:10]   # first 10 sales values
# Out:
# array([[10452, '07-11-2022', 'Fries', 3.49, 573.07, 'Online ',
#         ' Gift Card', 'Tom      Jackson', 'London'],
#        [10453, '07-11-2022', 'Beverages', 2.95, 745.76, 'Online ',
#         ' Gift Card', '       Pablo Perez', 'Madrid'],
#        [10454, '07-11-2022', 'Sides & Other', 4.99, 200.4, 'In-store ',
#         ' Gift Card', 'Joao    Silva', 'Lisbon'],
#        [10455, '08-11-2022', 'Burgers', 12.99, 569.67, 'In-store ',
#         ' Credit Card', 'Walter Muller', 'Berlin'],
#        [10456, '08-11-2022', 'Chicken Sandwiches', 9.95, 201.01,
#         'In-store ', ' Credit Card', 'Walter Muller', 'Berlin'],
#        [10457, '08-11-2022', 'Fries', 3.49, 573.07, 'In-store ',
#         ' Credit Card', 'Remy    Monet', 'Paris'],
#        [10459, '08-11-2022', 'Sides & Other', 4.99, 200.4, 'In-store ',
#         ' Credit Card', 'Walter Muller', 'Berlin'],
#        [10460, '09-11-2022', 'Burgers', 12.99, 554.27, 'In-store ',
#         ' Credit Card', 'Remy Monet', 'Paris'],
# ...

# %%
# Get shape of array
sales.shape
# Out:
# (254, 9)

# %%
# 2. Get data type of array
sales.dtype
# Out:
# dtype('O')

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {'Date': pd.to_datetime(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05',
                                 '2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05']),
        'Total': [100, 150, 120, 180, 200, 50, 75, 60, 90, 100]}
df = pd.DataFrame(data)


daily_sales = df.groupby('Date')['Total'].sum()

plt.figure(figsize=(10, 6))
plt.plot(daily_sales.index, daily_sales.values, marker='o')
plt.title("Daily Sales Trend")
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.grid(True)
plt.tight_layout()
plt.savefig('daily_sales_trend.png')

# %%
import matplotlib.pyplot as plt

labels = ['Category A', 'Category B', 'Category C', 'Category D']
sizes = [25, 30, 15, 30]
explode = (0, 0.1, 0, 0) # Explode the 2nd slice (Category B)
plt.figure(figsize=(8, 8))
plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Distribution of Categories')
plt.legend(labels, loc="best")
plt.tight_layout()
plt.savefig('category_distribution_pie_chart.png')

# %%
import matplotlib.pyplot as plt
import pandas as pd
data = {'Category': ['A', 'B', 'C', 'D', 'E'],
        'Value': [23, 45, 12, 55, 30]}
df = pd.DataFrame(data)
df = df.sort_values('Value', ascending=False)

plt.figure(figsize=(8, 6))
plt.bar(df['Category'], df['Value'], color='skyblue')
plt.title('Sample Bar Chart')
plt.xlabel('Category')
plt.ylabel('Value')
plt.tight_layout()
plt.savefig('sample_bar_chart.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data_line = {'Date': pd.to_datetime(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05']),
             'total_bill': [10.5, 12.8, 15.2, 11.9, 14.1],
             'tip': [1.5, 2.0, 2.5, 1.8, 2.2]}
df_line = pd.DataFrame(data_line)
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_line, x="Date", y="total_bill", marker='o')
sns.lineplot(data=df_line, x="Date", y="tip", marker='o')
plt.title("Total Bill and Tip over Time")
plt.xlabel("Date")
plt.ylabel("Amount ($)")
plt.legend(['Total Bill', 'Tip'])
plt.grid(True)
plt.tight_layout()
plt.savefig('line_plot_example_static.png')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
data_hist = pd.Series(np.random.normal(50, 15, 200)) # 200 random numbers
df_hist = pd.DataFrame({'Value': data_hist})
plt.figure(figsize=(8, 6))
sns.histplot(data=df_hist, x="Value", kde=True, bins=15)
plt.title("Distribution of Values (Histogram)")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.tight_layout()
plt.savefig('histogram_example_static.png')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {'Date': pd.to_datetime(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05',
                                 '2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05']),
        'Total': [100, 150, 120, 180, 200, 50, 75, 60, 90, 100]}
df = pd.DataFrame(data)

daily_sales = df.groupby('Date')['Total'].sum()

plt.figure(figsize=(10, 6))
plt.plot(daily_sales.index, daily_sales.values, marker='o')
plt.title("Daily Sales Trend")
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.grid(True)
plt.tight_layout()

plt.savefig('daily_sales_trend.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {'Date': pd.to_datetime(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05',
                               '2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05']),
        'Total': [100, 150, 120, 180, 200, 50, 75, 60, 90, 100]}
df = pd.DataFrame(data)

plt.figure(figsize=(10, 6))
sns.kdeplot(df['Total'], fill=True)
plt.title("Kernel Density Estimate of Total Sales")
plt.xlabel("Total Sales")
plt.ylabel("Density")
plt.grid(True)
plt.tight_layout()
plt.savefig('sales_kde.png')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = {'Date': pd.to_datetime(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05',
                               '2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05']),
        'Total': [100, 150, 120, 180, 200, 50, 75, 60, 90, 100]}
df = pd.DataFrame(data)
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['Total'])
plt.title("Box Plot of Total Sales")
plt.ylabel("Total Sales")
plt.tight_layout()
plt.savefig('sales_boxplot.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {'Date': pd.to_datetime(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05',
                               '2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05']),
        'Total': [100, 150, 120, 180, 200, 50, 75, 60, 90, 100]}
df = pd.DataFrame(data)

plt.figure(figsize=(8, 6))
sns.violinplot(y=df['Total'])
plt.title("Violin Plot of Total Sales")
plt.ylabel("Total Sales")
plt.tight_layout()
plt.savefig('sales_violinplot.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {'Date': pd.to_datetime(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05',
                               '2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05']),
        'Total': [100, 150, 120, 180, 200, 50, 75, 60, 90, 100]}
df = pd.DataFrame(data)
plt.figure(figsize=(10, 6))
sns.countplot(x='Total', data=df, order=df['Total'].value_counts().index)
plt.title("Count of Total Sales Values")
plt.xlabel("Total Sales")
plt.ylabel("Count")
plt.tight_layout()
plt.savefig('sales_countplot.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = {'Date': pd.to_datetime(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05',
                               '2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05']),
        'Total': [100, 150, 120, 180, 200, 50, 75, 60, 90, 100]}
df = pd.DataFrame(data)
daily_sales = df.groupby('Date')['Total'].sum().reset_index()
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Date', y='Total', data=daily_sales)
plt.title("Daily Sales Over Time")
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.grid(True)
plt.tight_layout()
plt.savefig('daily_sales_scatter.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = {'Date': pd.to_datetime(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05',
                               '2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05']),
        'Total': [100, 150, 120, 180, 200, 50, 75, 60, 90, 100]}
df = pd.DataFrame(data)
daily_sales = df.groupby('Date')['Total'].sum().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(x='Date', y='Total', data=daily_sales)
plt.title("Daily Sales Over Time")
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.grid(axis='y')
plt.tight_layout()
plt.savefig('daily_sales_bar.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = {'Date': pd.to_datetime(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05',
                               '2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05']),
        'Total': [100, 150, 120, 180, 200, 50, 75, 60, 90, 100]}
df = pd.DataFrame(data)
plt.figure(figsize=(8, 6))
sns.stripplot(x=df['Total'], jitter=True, size=8)
plt.title("Strip Plot of Total Sales")
plt.xlabel("Total Sales")
plt.tight_layout()
plt.savefig('sales_stripplot.png')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = {'Date': pd.to_datetime(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05',
                               '2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05']),
        'Total': [100, 150, 120, 180, 200, 50, 75, 60, 90, 100]}
df = pd.DataFrame(data)
plt.figure(figsize=(8, 6))
sns.swarmplot(x=df['Total'], size=8)
plt.title("Swarm Plot of Total Sales")
plt.xlabel("Total Sales")
plt.tight_layout()
plt.savefig('sales_swarmplot.png')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = {'Date': pd.to_datetime(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05',
                               '2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05']),
        'Total': [100, 150, 120, 180, 200, 50, 75, 60, 90, 100]}
df = pd.DataFrame(data)
daily_sales = df.groupby('Date')['Total'].sum().reset_index()
daily_sales['Day'] = daily_sales['Date'].dt.day
sns.set_style("whitegrid")
g = sns.jointplot(x="Day", y="Total", data=daily_sales, kind="scatter", marginal_kws=dict(bins=5))
g.ax_joint.set_title("Joint Plot of Daily Sales vs. Day of the Month", fontsize=12, pad=10)
g.set_axis_labels("Day of the Month", "Total Sales")
plt.savefig('sales_jointplot.png')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = {'Date': pd.to_datetime(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05',
                               '2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05']),
        'Total': [100, 150, 120, 180, 200, 50, 75, 60, 90, 100]}
df = pd.DataFrame(data)
plt.figure(figsize=(8, 6))
sns.boxenplot(y=df['Total'])
plt.title("Boxen Plot of Total Sales")
plt.ylabel("Total Sales")
plt.tight_layout()
plt.savefig('sales_boxenplot.png')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = {'Date': pd.to_datetime(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05',
                               '2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05']),
        'Total': [100, 150, 120, 180, 200, 50, 75, 60, 90, 100]}
df = pd.DataFrame(data)
daily_sales = df.groupby('Date')['Total'].sum().reset_index()
daily_sales['Day'] = daily_sales['Date'].dt.day
corr_matrix = daily_sales[['Day', 'Total']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap of Day and Total Sales")
plt.tight_layout()
plt.savefig('sales_heatmap.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = {
    'Date': pd.to_datetime(['2023-01-01', '2023-01-02', '2023-01-03']),
    'Product_A_Sales': [100, 150, 120],
    'Product_B_Sales': [50, 75, 60],
    'Product_C_Sales': [20, 30, 25]
}
df_clustermap = pd.DataFrame(data).set_index('Date')
sns.clustermap(df_clustermap, cmap='viridis', annot=True, fmt=".0f")
plt.savefig('sales_clustermap_example.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = {'Date': pd.to_datetime(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05',
                               '2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05']),
        'Total': [100, 150, 120, 180, 200, 50, 75, 60, 90, 100]}
df = pd.DataFrame(data)
daily_sales = df.groupby('Date')['Total'].sum().reset_index()
g = sns.relplot(x='Date', y='Total', kind='line', data=daily_sales)
g.fig.suptitle('Daily Sales Trend', y=1.03)
plt.savefig('daily_sales_relplot.png')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = {
    'Date': pd.to_datetime(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05']),
    'Total_Sales': [100, 150, 120, 180, 200],
    'Items_Sold': [20, 35, 25, 40, 50]
}
df_bubble = pd.DataFrame(data)
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Date', y='Total_Sales', size='Items_Sold', data=df_bubble,
                sizes=(100, 1000), legend='brief')
plt.title("Bubble Chart of Daily Sales and Items Sold")
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.tight_layout()
plt.savefig('sales_bubble_chart.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {
    'Date': pd.to_datetime(['2023-01-01', '2023-01-01', '2023-01-02', '2023-01-02',
                            '2023-01-03', '2023-01-03', '2023-01-04', '2023-01-04',
                            '2023-01-05', '2023-01-05']),
    'Category': ['Food', 'Drinks', 'Food', 'Drinks', 'Food',
                 'Drinks', 'Food', 'Drinks', 'Food', 'Drinks'],
    'Total_Sales': [80, 20, 100, 50, 90, 30, 120, 60, 150, 50]
}
df_stacked = pd.DataFrame(data)
pivot_df = df_stacked.pivot_table(index='Date', columns='Category', values='Total_Sales', aggfunc='sum')
pivot_df.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title("Daily Sales by Category")
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('daily_sales_stacked_bar.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = {
    'Date': pd.to_datetime(['2023-01-01', '2023-01-01', '2023-01-02', '2023-01-02',
                            '2023-01-03', '2023-01-03', '2023-01-04', '2023-01-04',
                            '2023-01-05', '2023-01-05']),
    'Category': ['Food', 'Drinks', 'Food', 'Drinks', 'Food',
                 'Drinks', 'Food', 'Drinks', 'Food', 'Drinks'],
    'Total_Sales': [80, 20, 100, 50, 90, 30, 120, 60, 150, 50]
}
df_grouped = pd.DataFrame(data)
plt.figure(figsize=(10, 6))
sns.barplot(x='Date', y='Total_Sales', hue='Category', data=df_grouped)
plt.title("Daily Sales by Category")
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('daily_sales_grouped_bar.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {'Date': pd.to_datetime(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05',
                               '2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05']),
        'Total': [100, 150, 120, 180, 200, 50, 75, 60, 90, 100]}
df = pd.DataFrame(data)
daily_sales = df.groupby('Date')['Total'].sum().reset_index()
daily_sales.set_index('Date', inplace=True)
daily_sales.plot.area(figsize=(10, 6))
plt.title("Daily Sales Trend (Area Plot)")
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.grid(True)
plt.tight_layout()
plt.savefig('daily_sales_area.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

data = {
    'Date_ordinal': [1, 2, 3, 4, 5],
    'Total_Sales': [100, 150, 120, 180, 200],
    'Items_Sold': [20, 35, 25, 40, 50]
}
df_3d = pd.DataFrame(data)
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df_3d['Date_ordinal'], df_3d['Total_Sales'], df_3d['Items_Sold'], c='r', marker='o')
ax.set_xlabel('Date (Ordinal)')
ax.set_ylabel('Total Sales')
ax.set_zlabel('Items Sold')
ax.set_title("3D Plot of Sales Data")
plt.savefig('sales_3d_plot.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import squarify

data = {
    'Category': ['Electronics', 'Electronics', 'Home Goods', 'Home Goods', 'Apparel'],
    'Sub_Category': ['Laptops', 'Smartphones', 'Furniture', 'Decor', 'Shirts'],
    'Sales': [1500, 800, 1200, 500, 600]
}
df_treemap = pd.DataFrame(data)
plt.figure(figsize=(10, 6))
sales = df_treemap['Sales'].values
labels = df_treemap['Sub_Category'].values
squarify.plot(sizes=sales, label=labels, alpha=0.8)
plt.title("Sales by Product Category")
plt.axis('off')

# Save the plot
plt.savefig('sales_treemap.png')

# %% [markdown]
# # :Conclusion
#
# # The analysis of restaurant sales data shows that a few categories and top items contribute most of the revenue, while payment preferences lean towards specific methods like cash or card. Sales trends highlight busy days and seasonal patterns, helping in staff and inventory planning. Overall, focusing on popular items, peak hours, and preferred payment methods can improve efficiency and boost profitability.

# %% [markdown]
# .
